# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})

        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()

    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"

    return available

# %%
if __name__ == '__main__':

    # add your user agent
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}

    # Loop for extracting product details from each link
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))


    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0    PlayStation 4 Slim 1TB Console - Black (Renewed)
# 1               PlayStation 4 500GB Console (Renewed)
# 2              Sony Playstation PS4 1TB Black Console
# 3   Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 4   Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...
# 5   Playstation Sony 4, 500GB Slim System [CUH-221...
# 6   PlayStation 4 Slim 500GB Console [Discontinued...
# 7   Sony PlayStation 4 PRO 1TB Gaming Console - Bl...
# 8   The Diofield Chronicle PlayStation 4 with Free...
# 9   PlayStation 4 Console - 1TB Slim Edition (Rene...
# 10  PS 4 Slim Seyted Upgraded 2TB Console with Wir...
# 11  ZOKIKY Wireless Controller for PS4,Remote for ...
# 12  Sony PlayStation 4 500GB Console Only (Certifi...
# 13  Newest Sony Playstation 4 PS4 1TB HDD Gaming C...
# 14                    MLB The Show 20 - PlayStation 4
# 15           Control Ultimate Edition - PlayStation 4
# 16  YOUXU Orange Gaming Headset for New Xbox One P...
# 17  Kingdom Hearts III - PlayStation 4 Deluxe Edition
# 18   PlayStation 4 Slim 1TB Console - Black (Renewed)
# 19  PlayStation 4 Slim 500GB Console [Discontinued...
# 20  Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 21           PlayStation 2 Slim Console PS2 (Renewed)
# 22              PlayStation 4 500GB Console (Renewed)
# 23  Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...
# 24  Playstation SONY 4, 500GB Slim System [CUH-221...
# 25  ECHTPower Charging Station for PS VR2 Sense Co...
# 26  CODOGOY PS5 Stand with 2 Cooling Fan, Dual Fas...
# 27  Wireless Controller for PS-4 Compatible with P...
# 28              PlayStation 4 500GB Console (Renewed)
# 29             Sony Playstation PS4 1TB Black Console
# 30   PlayStation 4 Slim 1TB Console - Black (Renewed)
# 31  Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...
# 32  Sony PlayStation 4 Slim Limited Edition 1TB Ga...
#
#                 rating        reviews                         availability
# 0   4.3 out of 5 stars  1,369 ratings   Only 1 left in stock - order soon.
# 1   4.1 out of 5 stars    699 ratings                             In Stock
# 2   4.6 out of 5 stars  1,202 ratings                             In Stock
# 3   4.3 out of 5 stars  1,213 ratings                             In Stock
# 4   4.0 out of 5 stars    658 ratings  Only 11 left in stock - order soon.
# 5   4.6 out of 5 stars    324 ratings    Only 5 left in stock - order soon
# 6   4.5 out of 5 stars  1,320 ratings                             In Stock
# 7   3.9 out of 5 stars    154 ratings   Only 3 left in stock - order soon.
# 8   3.8 out of 5 stars     19 ratings   Usually ships within 1 to 2 months
# 9   4.7 out of 5 stars     38 ratings                             In Stock
# 10  4.3 out of 5 stars     81 ratings                             In stock
# 11       Previous page                                            In Stock
# 12  3.0 out of 5 stars      7 ratings   Only 1 left in stock - order soon.
# 13  4.6 out of 5 stars    568 ratings    Only 9 left in stock - order soon
# 14  4.6 out of 5 stars    222 ratings                             In Stock
# 15  4.6 out of 5 stars    442 ratings    Only 3 left in stock - order soon
# 16  4.2 out of 5 stars    889 ratings
# 17  4.7 out of 5 stars  1,545 ratings    Only 1 left in stock - order soon
# 18  4.3 out of 5 stars  1,369 ratings   Only 1 left in stock - order soon.
# 19  4.5 out of 5 stars  1,320 ratings                             In Stock
# 20  4.3 out of 5 stars  1,213 ratings                             In Stock
# 21  4.1 out of 5 stars  1,075 ratings  Only 10 left in stock - order soon.
# 22  4.1 out of 5 stars    699 ratings                             In Stock
# 23  4.0 out of 5 stars    658 ratings  Only 11 left in stock - order soon.
# 24  4.7 out of 5 stars    364 ratings   Only 5 left in stock - order soon.
# 25  4.1 out of 5 stars    236 ratings                             In Stock
# 26  4.5 out of 5 stars    185 ratings                             In Stock
# 27  5.0 out of 5 stars                                            In Stock
# 28  4.1 out of 5 stars    699 ratings                             In Stock
# 29  4.6 out of 5 stars  1,202 ratings                             In Stock
# 30  4.3 out of 5 stars  1,369 ratings   Only 1 left in stock - order soon.
# 31  4.0 out of 5 stars    658 ratings  Only 11 left in stock - order soon.
# 32  4.3 out of 5 stars  1,213 ratings                             In Stock
